# %%
import os
#os.rename(r'/Volumes/MyCode/Rename/data/2a43a.jpg', r'/Volumes/MyCode/Rename/data/2a43a_num1.jpg')

# %%
i = 0
for filename in os.listdir('captcha'):
    name = filename.split('.')[0]
    rename = name + '_num' + str(i) + '.jpg'
    
    os.rename(r'/Volumes/MyCode/Rename/captcha/' + filename , r'/Volumes/MyCode/Rename/captcha/' + rename)
    i = i + 1
    print ('steps : ' + str(i))
# Out:
# steps : 1
# steps : 2
# steps : 3
# steps : 4
# steps : 5
# steps : 6
# steps : 7
# steps : 8
# steps : 9
# steps : 10
# steps : 11
# steps : 12
# steps : 13
# steps : 14
# steps : 15
# steps : 16
# steps : 17
# steps : 18
# steps : 19
# steps : 20
# steps : 21
# steps : 22
# steps : 23
# steps : 24
# steps : 25
# steps : 26
# steps : 27
# steps : 28
# steps : 29
# steps : 30
# steps : 31
# steps : 32
# steps : 33
# steps : 34
# steps : 35
# steps : 36
# steps : 37
# steps : 38
# steps : 39
# steps : 40
# steps : 41
# steps : 42
# steps : 43
# steps : 44
# steps : 45
# steps : 46
# steps : 47
# steps : 48
# steps : 49
# steps : 50
# steps : 51
# steps : 52
# steps : 53
# steps : 54
# steps : 55
# steps : 56
# steps : 57
# steps : 58
# steps : 59
# steps : 60
# steps : 61
# steps : 62
# steps : 63
# steps : 64
# steps : 65
# steps : 66
# steps : 67
# steps : 68
# steps : 69
# steps : 70
# steps : 71
# steps : 72
# steps : 73
# steps : 74
# steps : 75
# steps : 76
# steps : 77
# ...
